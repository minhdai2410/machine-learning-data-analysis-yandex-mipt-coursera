# %% [markdown]
# # Sklearn

# %% [markdown]
# ## Bike Sharing Demand
# Задача на kaggle: https://www.kaggle.com/c/bike-sharing-demand
#
# По историческим данным о прокате велосипедов и погодным условиям необходимо оценить спрос на прокат велосипедов.
#
# В исходной постановке задачи доступно 11 признаков: https://www.kaggle.com/c/prudential-life-insurance-assessment/data
#
# В наборе признаков присутсвуют вещественные, категориальные, и бинарные данные.
#
# Для демонстрации используется обучающая выборка из исходных данных train.csv, файлы для работы прилагаются.

# %% [markdown]
# ### Библиотеки

# %%
from sklearn import linear_model, metrics 
from sklearn.model_selection import cross_validate, GridSearchCV
import numpy as np
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Загрузка данных

# %%
raw_data = pd.read_csv('bike_sharing_demand.csv', header = 0, sep = ',')

# %%
raw_data.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %% [markdown]
# ***datetime*** - hourly date + timestamp
#
# ***season*** -  1 = spring, 2 = summer, 3 = fall, 4 = winter
#
# ***holiday*** - whether the day is considered a holiday
#
# ***workingday*** - whether the day is neither a weekend nor holiday
#
# ***weather*** - 1: Clear, Few clouds, Partly cloudy, Partly cloudy
# 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
# 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
# 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
#
# ***temp*** - temperature in Celsius
#
# ***atemp*** - "feels like" temperature in Celsius
#
# ***humidity*** - relative humidity
#
# ***windspeed*** - wind speed
#
# ***casual*** - number of non-registered user rentals initiated
#
# ***registered*** - number of registered user rentals initiated
#
# ***count*** - number of total rentals

# %%
print (raw_data.shape)
# Out:
# (10886, 12)

# %%
raw_data.isnull().values.any()
# Out:
# False

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### Типы признаков

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
# datetime      10886 non-null object
# season        10886 non-null int64
# holiday       10886 non-null int64
# workingday    10886 non-null int64
# weather       10886 non-null int64
# temp          10886 non-null float64
# atemp         10886 non-null float64
# humidity      10886 non-null int64
# windspeed     10886 non-null float64
# casual        10886 non-null int64
# registered    10886 non-null int64
# count         10886 non-null int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.6+ KB

# %%
raw_data.datetime = raw_data.datetime.apply(pd.to_datetime)

# %%
raw_data['month'] = raw_data.datetime.apply(lambda x : x.month)
raw_data['hour'] = raw_data.datetime.apply(lambda x : x.hour)

# %%
raw_data.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  month  hour
# 0        81        0.0       3          13     16      1     0
# 1        80        0.0       8          32     40      1     1
# 2        80        0.0       5          27     32      1     2
# 3        75        0.0       3          10     13      1     3
# 4        75        0.0       0           1      1      1     4

# %% [markdown]
# #### Обучение и отложенный тест

# %%
train_data = raw_data.iloc[:-1000, :]
hold_out_test_data = raw_data.iloc[-1000:, :]

# %%
print (raw_data.shape, train_data.shape, hold_out_test_data.shape)
# Out:
# (10886, 14) (9886, 14) (1000, 14)

# %%
print ('train period from {} to {}'.format(train_data.datetime.min(), train_data.datetime.max()))
print ('evaluation period from {} to {}'.format(hold_out_test_data.datetime.min(), hold_out_test_data.datetime.max()))
# Out:
# train period from 2011-01-01 00:00:00 to 2012-10-16 06:00:00
# evaluation period from 2012-10-16 07:00:00 to 2012-12-19 23:00:00

# %% [markdown]
# #### Данные и целевая функция

# %%
#обучение
train_labels = train_data['count'].values
train_data = train_data.drop(['datetime', 'count'], axis = 1)

# %%
#тест
test_labels = hold_out_test_data['count'].values
test_data = hold_out_test_data.drop(['datetime', 'count'], axis = 1)

# %% [markdown]
# #### Целевая функция на обучающей выборке и на отложенном тесте

# %%
pylab.figure(figsize = (16, 6))

pylab.subplot(1,2,1)
pylab.hist(train_labels)
pylab.title('train data')

pylab.subplot(1,2,2)
pylab.hist(test_labels)
pylab.title('test data')
# Out:
# Text(0.5, 1.0, 'test data')

# %% [markdown]
# #### Числовые признаки

# %%
numeric_columns = ['temp', 'atemp', 'humidity', 'windspeed', 'casual', 'registered', 'month', 'hour']

# %%
train_data = train_data[numeric_columns]
test_data = test_data[numeric_columns]

# %%
train_data.head()
# Out:
#    temp   atemp  humidity  windspeed  casual  registered  month  hour
# 0  9.84  14.395        81        0.0       3          13      1     0
# 1  9.02  13.635        80        0.0       8          32      1     1
# 2  9.02  13.635        80        0.0       5          27      1     2
# 3  9.84  14.395        75        0.0       3          10      1     3
# 4  9.84  14.395        75        0.0       0           1      1     4

# %%
test_data.head()
# Out:
#        temp   atemp  humidity  windspeed  casual  registered  month  hour
# 9886  17.22  21.210        67     6.0032      20         505     10     7
# 9887  18.04  21.970        62     0.0000      35         800     10     8
# 9888  19.68  23.485        55    16.9979      32         323     10     9
# 9889  20.50  24.240        48    19.0012      65         157     10    10
# 9890  20.50  24.240        45    27.9993      56         172     10    11

# %% [markdown]
# ### Модель

# %%
regressor = linear_model.SGDRegressor(random_state = 0)

# %%
regressor.fit(train_data, train_labels)
metrics.mean_absolute_error(test_labels, regressor.predict(test_data))
# Out:
# 31851310300813.895

# %%
print (test_labels[:10])
# Out:
# [525 835 355 222 228 325 328 308 346 446]

# %%
print (regressor.predict(test_data)[:10])
# Out:
# [6.38237236e+13 9.93774167e+13 4.50263651e+13 3.24238509e+13
#  3.17252459e+13 4.39305995e+13 4.44982989e+13 4.41783289e+13
#  4.68904479e+13 5.83210989e+13]

# %%
regressor.coef_
# Out:
# array([ 1.51022653e+11, -5.06697186e+10,  4.53044112e+10, -7.46986340e+10,
#         1.80525319e+11,  1.10015690e+11, -3.01811345e+09,  8.39465294e+10])

# %% [markdown]
# ### Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
#создаем стандартный scaler
scaler = StandardScaler()
scaler.fit(train_data, train_labels)
scaled_train_data = scaler.transform(train_data)
scaled_test_data = scaler.transform(test_data)

# %%
regressor.fit(scaled_train_data, train_labels)
metrics.mean_absolute_error(test_labels, regressor.predict(scaled_test_data))
# Out:
# 0.11793762963431477

# %%
test_labels[:10]
# Out:
# array([525, 835, 355, 222, 228, 325, 328, 308, 346, 446], dtype=int64)

# %%
regressor.predict(scaled_test_data)[:10]
# Out:
# array([524.82767322, 834.83176277, 354.85768824, 221.89221002,
#        227.84049612, 324.88196372, 327.8982227 , 307.9347954 ,
#        345.90146969, 445.90141764])

# %% [markdown]
# ### Подозрительно хорошо?

# %%
regressor.coef_
# Out:
# array([ 1.41019246e+00, -1.40725539e+00,  1.45346928e-02, -4.38984175e-02,
#         5.08589954e+01,  1.48004811e+02, -8.23376876e-03,  6.37720415e-03])

# %%
list(map(lambda x : round(x, 2), regressor.coef_))
# Out:
# [1.41, -1.41, 0.01, -0.04, 50.86, 148.0, -0.01, 0.01]

# %%
train_data.head()
# Out:
#    temp   atemp  humidity  windspeed  casual  registered  month  hour
# 0  9.84  14.395        81        0.0       3          13      1     0
# 1  9.02  13.635        80        0.0       8          32      1     1
# 2  9.02  13.635        80        0.0       5          27      1     2
# 3  9.84  14.395        75        0.0       3          10      1     3
# 4  9.84  14.395        75        0.0       0           1      1     4

# %%
train_labels[:10]
# Out:
# array([16, 40, 32, 13,  1,  1,  2,  3,  8, 14], dtype=int64)

# %%
np.all(train_data.registered + train_data.casual == train_labels)
# Out:
# True

# %%
train_data.drop(['casual', 'registered'], axis = 1, inplace = True)
test_data.drop(['casual', 'registered'], axis = 1, inplace = True)

# %%
scaler.fit(train_data, train_labels)
scaled_train_data = scaler.transform(train_data)
scaled_test_data = scaler.transform(test_data)

# %%
regressor.fit(scaled_train_data, train_labels)
metrics.mean_absolute_error(test_labels, regressor.predict(scaled_test_data))
# Out:
# 121.81123864993025

# %%
list(map(lambda x : round(x, 2), regressor.coef_))
# Out:
# [31.03, 29.96, -41.93, 6.17, 14.08, 49.6]

# %% [markdown]
# ### Pipeline

# %%
from sklearn.pipeline import Pipeline

# %%
#создаем pipeline из двух шагов: scaling и классификация
pipeline = Pipeline(steps = [('scaling', scaler), ('regression', regressor)])

# %%
pipeline.fit(train_data, train_labels)
metrics.mean_absolute_error(test_labels, pipeline.predict(test_data))
# Out:
# 121.81123864993025

# %% [markdown]
# ### Подбор параметров

# %%
pipeline.get_params().keys()
# Out:
# dict_keys(['memory', 'steps', 'scaling', 'regression', 'scaling__copy', 'scaling__with_mean', 'scaling__with_std', 'regression__alpha', 'regression__average', 'regression__early_stopping', 'regression__epsilon', 'regression__eta0', 'regression__fit_intercept', 'regression__l1_ratio', 'regression__learning_rate', 'regression__loss', 'regression__max_iter', 'regression__n_iter', 'regression__n_iter_no_change', 'regression__penalty', 'regression__power_t', 'regression__random_state', 'regression__shuffle', 'regression__tol', 'regression__validation_fraction', 'regression__verbose', 'regression__warm_start'])

# %%
parameters_grid = {
    'regression__loss' : ['huber', 'epsilon_insensitive', 'squared_loss', ],
    'regression__n_iter' : [3, 5, 10, 50], 
    'regression__penalty' : ['l1', 'l2', 'none'],
    'regression__alpha' : [0.0001, 0.01],
    'scaling__with_mean' : [0., 0.5],
}

# %%
metrics.SCORERS.keys()
# Out:
# dict_keys(['explained_variance', 'r2', 'neg_median_absolute_error', 'neg_mean_absolute_error', 'neg_mean_squared_error', 'neg_mean_squared_log_error', 'accuracy', 'roc_auc', 'balanced_accuracy', 'average_precision', 'neg_log_loss', 'brier_score_loss', 'adjusted_rand_score', 'homogeneity_score', 'completeness_score', 'v_measure_score', 'mutual_info_score', 'adjusted_mutual_info_score', 'normalized_mutual_info_score', 'fowlkes_mallows_score', 'precision', 'precision_macro', 'precision_micro', 'precision_samples', 'precision_weighted', 'recall', 'recall_macro', 'recall_micro', 'recall_samples', 'recall_weighted', 'f1', 'f1_macro', 'f1_micro', 'f1_samples', 'f1_weighted'])

# %%
grid_cv = GridSearchCV(pipeline, parameters_grid, scoring = 'neg_mean_absolute_error', cv = 4)

# %%
# %%time
grid_cv.fit(train_data, train_labels)
# Out:
# Wall time: 22.2 s
# GridSearchCV(cv=4, error_score='raise-deprecating',
#        estimator=Pipeline(memory=None,
#      steps=[('scaling', StandardScaler(copy=True, with_mean=True, with_std=True)), ('regression', SGDRegressor(alpha=0.0001, average=False, early_stopping=False, epsilon=0.1,
#        eta0=0.01, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='invscaling', loss=...dom_state=0, shuffle=True, tol=None, validation_fraction=0.1,
#        verbose=0, warm_start=False))]),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'regression__loss': ['huber', 'epsilon_insensitive', 'squared_loss'], 'regression__n_iter': [3, 5, 10, 50], 'regression__penalty': ['l1', 'l2', 'none'], 'regression__alpha': [0.0001, 0.01], 'scaling__with_mean': [0.0, 0.5]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='neg_mean_absolute_error', verbose=0)

# %%
print (-grid_cv.best_score_)
print (grid_cv.best_params_)
# Out:
# 108.61449660348289
# {'regression__alpha': 0.01, 'regression__loss': 'squared_loss', 'regression__n_iter': 3, 'regression__penalty': 'l2', 'scaling__with_mean': 0.0}

# %% [markdown]
# ### Оценка по отложенному тесту

# %%
metrics.mean_absolute_error(test_labels, grid_cv.best_estimator_.predict(test_data))
# Out:
# 119.98978845935378

# %%
np.mean(test_labels)
# Out:
# 232.159

# %%
test_predictions = grid_cv.best_estimator_.predict(test_data)

# %%
print (test_labels[:10])
# Out:
# [525 835 355 222 228 325 328 308 346 446]

# %%
print (test_predictions[:10])
# Out:
# [139.60470681 159.80765341 207.55935972 237.76288054 257.83836668
#  267.44558034 272.49537469 297.70688522 304.29818873 313.58821156]

# %%
pylab.figure(figsize=(16, 6))

pylab.subplot(1,2,1)
pylab.grid(True)
pylab.scatter(train_labels, pipeline.predict(train_data), alpha=0.5, color = 'red')
pylab.scatter(test_labels, pipeline.predict(test_data), alpha=0.5, color = 'blue')
pylab.title('no parameters setting')
pylab.xlim(-100,1100)
pylab.ylim(-100,1100)

pylab.subplot(1,2,2)
pylab.grid(True)
pylab.scatter(train_labels, grid_cv.best_estimator_.predict(train_data), alpha=0.5, color = 'red')
pylab.scatter(test_labels, grid_cv.best_estimator_.predict(test_data), alpha=0.5, color = 'blue')
pylab.title('grid search')
pylab.xlim(-100,1100)
pylab.ylim(-100,1100)
# Out:
# (-100, 1100)

# %% [markdown]
# ## Выводы записавшегося на курсы
# Перед обучением модели надо капитально поработать над данными:
# * Преобразовывать данные к нужному типу, если они были загружены не в том формате
# * Делать разделение на отложенную и тестовую по времени, чтобы не брать информацию из будущего. При таком разделении выборки  возможно переобучение, так как данные будут браться из разных времен. В настоящем у нас есть информация толкьо о прошлом, но не о будущем. При взятии информации из будущего возникнет так называемая утечка.
# * Удаляем из обучения Id сущностей и другие неинформативные признаки
# * Убирать лишние признаки по практическим соображениям
# * Масштабировать признаки, чтобы одни признаки не затмили другие, что приведёт к большой ошибке
# * Не использовать признаки, по которым однозначно восстанавливается функция
# * Подбор параметров по кросс валидации. Масштабирование происходит для каждой подвыборки.
# * Можно использовать pipeline, чтобы сделать единый интерфейс для выполнения некоторой последовательности команд по обработке данных. Удобен для поиска по сетке, к примеру
# * Если по модулю признаки разные, получаем большие веса. Но при использовании регуляризации все плохо, поэтому надо масштабировать.
# * На обучающей выборке используется кросс валидация (часть фолдов - обучающая выборка, другая часть - тестовая), а на отложенной (тестовой) выборке проверяем итоговое качество
